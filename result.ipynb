# %%
# %pip install matplotlib numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 17.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 22.4 MB/s eta 0:00:00 MB/s eta 0:00:0101
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 21.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib] 7/8 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python3
import matplotlib.pyplot as plt
import numpy as np

# %%
# utilizacao de cada dispositivo de um servidor de acordo com a quantidade de clientes

# cliente d1 d2 d3
# 1 8.000000 5.000000 4.000000
# 2 11.764706 6.470588 4.941176
# 3 16.121827 7.791878 5.705584
# 4 21.063239 8.946015 6.311568

#  Esta é a minha entrada gere um grafico que mostre a utilização de cada dispositivo de acordo com a quantidade de clientes



# Dados de entrada
# clientes = [1, 2, 3, 4]
# d1 = [8.000000, 11.764706, 16.121827, 21.063239]
# d2 = [5.000000, 6.470588, 7.791878, 8.946015]
# As variáveis clientes, d1, d2 e d3 já estão definidas a partir dos dados de resposta_vs_clientes.txt

# Ler os dados do arquivo texto
dados = np.loadtxt('resposta_vs_clientes.txt')
clientes = dados[:, 0].astype(int).tolist()
d1 = dados[:, 1].tolist()
d2 = dados[:, 2].tolist()
d3 = dados[:, 3].tolist()

# Criar gráfico
plt.figure(figsize=(10, 6))
plt.plot(clientes, d1, marker='o', label='Dispositivo 1')
plt.plot(clientes, d2, marker='o', label='Dispositivo 2')
plt.plot(clientes, d3, marker='o', label='Dispositivo 3')

# Adicionar título e rótulos
plt.title('Tempo de resposta dos Dispositivos de Acordo com a Quantidade de Clientes')
plt.xlabel('Número de Clientes')
plt.ylabel('Tempo de Resposta (minutos)')
plt.xticks(np.arange(1, 5, 1))
plt.yticks(np.arange(0, 25, 5))
plt.grid()
plt.legend()
plt.show()

# %%
# Ler os dados de utilização do arquivo texto
dados_utilizacao = np.loadtxt('utilizacao_vs_clientes.txt')
clientes_util = dados_utilizacao[:, 0].astype(int).tolist()
u1 = dados_utilizacao[:, 1].tolist()
u2 = dados_utilizacao[:, 2].tolist()
u3 = dados_utilizacao[:, 3].tolist()

# Criar gráfico de utilização
plt.figure(figsize=(10, 6))
plt.plot(clientes_util, u1, marker='o', label='Dispositivo 1')
plt.plot(clientes_util, u2, marker='o', label='Dispositivo 2')
plt.plot(clientes_util, u3, marker='o', label='Dispositivo 3')

plt.title('Utilização dos Dispositivos de Acordo com a Quantidade de Clientes')
plt.xlabel('Número de Clientes')
plt.ylabel('Utilização (%)')
plt.xticks(np.arange(min(clientes_util), max(clientes_util)+1, 1))
plt.grid()
plt.legend()
plt.show()
